# %% [markdown]
# ## Packages

# %%
# ----- Tensorflow -----
import tensorflow as tf
import tensorflow_datasets as tfds
from keras import regularizers as reg
from keras import optimizers
from keras.models import Model, load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt

from keras.layers import Input, Dropout, Dense, Conv2D, MaxPooling2D, Flatten, Concatenate, AveragePooling2D, Rescaling

# ----- Utility functions -----
from utils import load_data, plot_hist, augment_layer, preprocess_data

# %% [markdown]
# ## Load Data

# %%
data_dir = r'C:\Users\andly'
BATCH_SIZE = 32
train, test, val = load_data(data_dir, perc=5, batch_size=BATCH_SIZE)

# %% [markdown]
# ### Architectures
# Before we begin building complex architectures for the CNN model, we must establish a baseline classifier which we will attempt to beat. This common-sense baseline will tell us if we are moving in the right direction. In our case, we can choose a simple random classifier with a threshold of 0.5 since we have a binary classification problem where half of the samples belong to class A and the remaining 50% belong to class B. We could also specify a 'simple' machine learning algorithm as a baseline, but although we do not do this explicitly, we will aim to beat the trained models in question 1 as CNNs has some properties that make them superior to non-deep learning algorithms and feedforward neural networks (Chollet, 2021).
#
# At this point, the first thing we want to achieve is statistical power, i.e. to cross the threshold of our baseline classifier by developing a small model. To do so, we focus on parameters such as the loss function, batch_size, learning rate, etc. Due to the way we represent the labels, we will use the softmax activation and the loss function categorical cross entropy rather than sigmoid and binary cross entropy, however, this will not change the results of our models.
#
# Kommentar: Husk arkitektur (størrelse/bredde) og default valg af optimizer (adam) + valgte parametre = default settings + FLOW CHART

# %%
# ----- Relatively Simple Convnet from DLPR -----
inputs = Input(shape=(96, 96, 3))
x = Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = Flatten()(x)
outputs = Dense(2, activation="softmax")(x)
model = Model(inputs=inputs, outputs=outputs)

# ----- Model summary -----
model.summary()
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
# ----- Configure model -----
model.compile(optimizer=opt,
			  loss='categorical_crossentropy',
			  metrics=['accuracy'])

# ----- Train model -----
history = model.fit(train,
					epochs = 50,
					validation_data= val)

# ----- Plot performance -----
plot_hist(history)
# Out:
# Model: "model_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_22 (InputLayer)       [(None, 96, 96, 3)]       0
#
#  conv2d_105 (Conv2D)         (None, 94, 94, 32)        896
#
#  max_pooling2d_84 (MaxPoolin  (None, 47, 47, 32)       0
#  g2D)
#
#  conv2d_106 (Conv2D)         (None, 45, 45, 64)        18496
#
#  max_pooling2d_85 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  conv2d_107 (Conv2D)         (None, 20, 20, 128)       73856
#
#  max_pooling2d_86 (MaxPoolin  (None, 10, 10, 128)      0
#  g2D)
#
#  conv2d_108 (Conv2D)         (None, 8, 8, 256)         295168
#
#  max_pooling2d_87 (MaxPoolin  (None, 4, 4, 256)        0
#  g2D)
#
#  conv2d_109 (Conv2D)         (None, 2, 2, 256)         590080
#
#  flatten_21 (Flatten)        (None, 1024)              0
#
#  dense_21 (Dense)            (None, 2)                 2050
#
# =================================================================
# Total params: 980,546
# Trainable params: 980,546
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#
# Epoch 39/50
# 410/410 [==============================] - 9s 22ms/step - loss: 0.0348 - accuracy: 0.9888 - val_loss: 2.1362 - val_accuracy: 0.7698
# Epoch 40/50
# 410/410 [==============================] - 9s 23ms/step - loss: 0.0224 - accuracy: 0.9924 - val_loss: 2.5826 - val_accuracy: 0.7411
# Epoch 41/50
# 410/410 [==============================] - 9s 22ms/step - loss: 0.0378 - accuracy: 0.9880 - val_loss: 1.8969 - val_accuracy: 0.7741
# Epoch 42/50
# 410/410 [==============================] - 10s 23ms/step - loss: 0.0212 - accuracy: 0.9924 - val_loss: 2.1948 - val_accuracy: 0.7741
# Epoch 43/50
# 410/410 [==============================] - 10s 23ms/step - loss: 0.0294 - accuracy: 0.9903 - val_loss: 2.2287 - val_accuracy: 0.7680
# Epoch 44/50
# 410/410 [==============================] - 10s 23ms/step - loss: 0.0205 - accuracy: 0.9932 - val_loss: 2.2283 - val_accuracy: 0.7766
# Epoch 45/50
# 410/410 [==============================] - 10s 25ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 2.1452 - val_accuracy: 0.7601
# Epoch 46/50
# 410/410 [==============================] - 9s 23ms/step - loss: 0.0333 - accuracy: 0.9892 - val_loss: 2.1033 - val_accuracy: 0.7564
# Epoch 47/50
# 410/410 [==============================] - 9s 23ms/step - loss: 0.0223 - accuracy: 0.9925 - val_loss: 1.9588 - val_accuracy: 0.7827
# Epoch 48/50
# 410/410 [==============================] - 9s 23ms/step - loss: 0.0330 - accuracy: 0.9904 - val_loss: 2.2299 - val_accuracy: 0.7485
# Epoch 49/50
# 410/410 [==============================] - 9s 23ms/step - loss: 0.0334 - accuracy: 0.9908 - val_loss: 1.9875 - val_accuracy: 0.7485
# Epoch 50/50
# 410/410 [==============================] - 9s 22ms/step - loss: 0.0280 - accuracy: 0.9921 - val_loss: 1.9115 - val_accuracy: 0.7686

# %% [markdown]
# ## Evaluation of simple model
#
# The first results from the experiment with the simple model shows a promising accuracy of 83.xx%, which is significantly higher than the random classifier that has the expected prediction of 50/50. Futhermore, the plots of the accuracy over 30 epochs shows a rather fluctuating accuracy score, which could be an indication of a learning rate that is too high. Thus, for the next step in the procedure, we adjust the learning rate aswell as trying a setting with Stochastic Gradient Descent (SGD) as an alternative optimizer.
#
# According to Goodfellow et al. (2016) perhaps the most important hyperparameter is the learning rate, and if we only had time to tune a single parameter, it should be this one (p. 424). The learning rate controls the speed of the gradient descent process, i.e. how much to adjust the parameters in a single step (Chollet, 2021). If the learning rate is too small, results in too many iterations and the possibility of getting stuck at a local minimum. In contrary, too high of a learning rate could result in divergent behavior. Therefore, we try different values of the learning rate using the Adam optimizer. Due to time constraints of training with different optimizers and learning rates, we will only compare the Adam and (SGD) from Keras. This is reasonable because one... adaptive vs SGD

# %%
## Hyperparameters for tuning learning rate and optimizer

learning_rates = [0.01, 0.001, 0.0001, 0.00001]
momentum = [0.99, 0.9]
nesterov = [True, False]

# %% [markdown]
# ## Optimizer: Adam

# %%
def simple_model():
	inputs = Input(shape=(96, 96, 3))
	x = Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
	x = MaxPooling2D(pool_size=2)(x)
	x = Conv2D(filters=64, kernel_size=3, activation="relu")(x)
	x = MaxPooling2D(pool_size=2)(x)
	x = Conv2D(filters=128, kernel_size=3, activation="relu")(x)
	x = MaxPooling2D(pool_size=2)(x)
	x = Conv2D(filters=256, kernel_size=3, activation="relu")(x)
	x = MaxPooling2D(pool_size=2)(x)
	x = Conv2D(filters=256, kernel_size=3, activation="relu")(x)
	x = Flatten()(x)
	outputs = Dense(2, activation="softmax")(x)
	model = Model(inputs=inputs, outputs=outputs)

	return model

# ----- Define subplot grid -----
t=1
fig, axis = plt.subplots(nrows=4, ncols=2, figsize=(10, 6))
plt.subplots_adjust(hspace=0.8)
fig.suptitle("Training and validation accuracy for different learning rates with Adam", fontsize=12, y=1)

# Try different learning rates for Adam optimizer
for i in range(len(learning_rates)):
	opt = tf.keras.optimizers.Nadam(learning_rate=learning_rates[i])

	current_model = simple_model()

	print('Learning rate: ', i)

	# ----- Configure model -----
	current_model.compile(optimizer=opt,
			  	loss='categorical_crossentropy',
			  metrics=['accuracy'])

	# ----- Train model -----
	history = current_model.fit(train,
						epochs=50,
						validation_data=val)

	# ----- Plot performance -----
	acc = history.history['accuracy']
	val_acc = history.history['val_accuracy']
	loss = history.history['loss']
	val_loss = history.history['val_loss']
	epochs = range(1, len(acc) + 1)

	axis = plt.subplot(4, 2, t)
	axis.plot(epochs, acc,'r--', label='Training')
	axis.plot(epochs, val_acc, 'r', label='Validation')
	axis.set_title('Accuracy, lr=' + str(learning_rates[i]), fontsize=6)

	axis = plt.subplot(4, 2, t+1)
	axis.plot(epochs, loss, 'r--', label='Training')
	axis.plot(epochs, val_loss, 'r', label='Validation')
	axis.set_title('Losses, lr=' + str(learning_rates[i]), fontsize=6)

	t=t+2

plt.legend(loc=(0.5,-1.1))
plt.show()
# Out:
# Learning rate:  0
# Epoch 1/50
# 410/410 [==============================] - 12s 26ms/step - loss: 1.5071 - accuracy: 0.5032 - val_loss: 0.6938 - val_accuracy: 0.4969
# Epoch 2/50
# 410/410 [==============================] - 10s 25ms/step - loss: 0.6935 - accuracy: 0.5015 - val_loss: 0.6938 - val_accuracy: 0.4969
# Epoch 3/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.6935 - accuracy: 0.4992 - val_loss: 0.6938 - val_accuracy: 0.4969
# Epoch 4/50
# 410/410 [==============================] - 10s 25ms/step - loss: 0.6935 - accuracy: 0.5003 - val_loss: 0.6938 - val_accuracy: 0.4969
# Epoch 5/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.6935 - accuracy: 0.5021 - val_loss: 0.6938 - val_accuracy: 0.4969
# Epoch 6/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.6935 - accuracy: 0.5026 - val_loss: 0.6938 - val_accuracy: 0.4969
# Epoch 7/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.6935 - accuracy: 0.5006 - val_loss: 0.6938 - val_accuracy: 0.4969
# Epoch 8/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4245 - accuracy: 0.8070 - val_loss: 0.4327 - val_accuracy: 0.7991
# Epoch 36/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4228 - accuracy: 0.8093 - val_loss: 0.4349 - val_accuracy: 0.7991
# Epoch 37/50
# 410/410 [==============================] - 11s 27ms/step - loss: 0.4203 - accuracy: 0.8112 - val_loss: 0.4353 - val_accuracy: 0.7967
# Epoch 38/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4184 - accuracy: 0.8127 - val_loss: 0.4353 - val_accuracy: 0.7961
# Epoch 39/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4157 - accuracy: 0.8127 - val_loss: 0.4394 - val_accuracy: 0.7985
# Epoch 40/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4141 - accuracy: 0.8145 - val_loss: 0.4395 - val_accuracy: 0.7998
# Epoch 41/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4121 - accuracy: 0.8161 - val_loss: 0.4351 - val_accuracy: 0.7998
# Epoch 42/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4107 - accuracy: 0.8143 - val_loss: 0.4328 - val_accuracy: 0.8004
# Epoch 43/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4087 - accuracy: 0.8161 - val_loss: 0.4339 - val_accuracy: 0.8016
# Epoch 44/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4061 - accuracy: 0.8193 - val_loss: 0.4358 - val_accuracy: 0.8010
# Epoch 45/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4042 - accuracy: 0.8180 - val_loss: 0.4369 - val_accuracy: 0.7991
# Epoch 46/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.4028 - accuracy: 0.8188 - val_loss: 0.4325 - val_accuracy: 0.8022
# Epoch 47/50
# 410/410 [==============================] - 10s 26ms/step - loss: 0.4004 - accuracy: 0.8215 - val_loss: 0.4350 - val_accuracy: 0.8016
# Epoch 48/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.3982 - accuracy: 0.8227 - val_loss: 0.4371 - val_accuracy: 0.8010
# Epoch 49/50
# 410/410 [==============================] - 11s 26ms/step - loss: 0.3955 - accuracy: 0.8230 - val_loss: 0.4405 - val_accuracy: 0.8004
# Epoch 50/50
# 410/410 [==============================] - 10s 26ms/step - loss: 0.3944 - accuracy: 0.8247 - val_loss: 0.4372 - val_accuracy: 0.8004

# %% [markdown]
# ## Optimizer: SGD

# %%
# Try different learning rates, momentum, and nesterov for SGD optimizer
for i in range(len(learning_rates)):
	
	# ----- Define subplot grid -----
	t=1
	fig, axis = plt.subplots(nrows=4, ncols=2, figsize=(16, 16))
	plt.subplots_adjust(hspace=0.8)
	fig.suptitle("Model accuracy for different learning- and momentum rates for SGD", fontsize=12, y=1)

	for m in range(len(momentum)):
		for n in range(len(nesterov)):
			
			current_model = simple_model()

			opt = tf.keras.optimizers.SGD(learning_rate=learning_rates[i],
										  momentum=momentum[m],
										  nesterov=nesterov[n])

			# ----- Configure model -----
			current_model.compile(optimizer=opt,
						loss='categorical_crossentropy',
					metrics=['accuracy'])

			# ----- Train model -----
			history = current_model.fit(train,
								epochs=50,
								validation_data=val)

			# ----- Plot performance -----
			acc = history.history['accuracy']
			val_acc = history.history['val_accuracy']
			loss = history.history['loss']
			val_loss = history.history['val_loss']
			epochs = range(1, len(acc) + 1)

			axis = plt.subplot(4, 2, t)
			axis.plot(epochs, acc,'r--', label='Training')
			axis.plot(epochs, val_acc, 'r', label='Validation')
			axis.set_title('Accuracy, lr=' + str(learning_rates[i]) + ', momen=' + str(momentum[m]) + ', nest=' + str(nesterov[n]), fontsize=12)

			axis = plt.subplot(4, 2, t+1)
			axis.plot(epochs, loss, 'r--', label='Training')
			axis.plot(epochs, val_loss, 'r', label='Validation')
			axis.set_title('Losses, lr=' + str(learning_rates[i]) + ', momen=' + str(momentum[m]) + ', nest=' + str(nesterov[n]), fontsize=12)
			t=t+2
	plt.legend(loc=(0.7,-0.5))
	plt.savefig('lr=' + str(learning_rates[i]) + ', momen=' + str(momentum[m]) + ', nest=' + str(nesterov[n]) + '.png')
	plt.show()
# Out:
# Epoch 1/50
# 410/410 [==============================] - 10s 22ms/step - loss: 0.5798 - accuracy: 0.6840 - val_loss: 0.4900 - val_accuracy: 0.7607
# Epoch 2/50
# 410/410 [==============================] - 9s 21ms/step - loss: 0.4778 - accuracy: 0.7803 - val_loss: 0.4835 - val_accuracy: 0.7698
# Epoch 3/50
# 410/410 [==============================] - 9s 21ms/step - loss: 0.4454 - accuracy: 0.8003 - val_loss: 0.4612 - val_accuracy: 0.7778
# Epoch 4/50
# 410/410 [==============================] - 9s 21ms/step - loss: 0.4385 - accuracy: 0.8032 - val_loss: 0.4832 - val_accuracy: 0.7790
# Epoch 5/50
# 410/410 [==============================] - 9s 21ms/step - loss: 0.4262 - accuracy: 0.8123 - val_loss: 0.5409 - val_accuracy: 0.7357
# Epoch 6/50
# 410/410 [==============================] - 9s 21ms/step - loss: 0.4324 - accuracy: 0.8057 - val_loss: 0.4665 - val_accuracy: 0.7790
# Epoch 7/50
# 410/410 [==============================] - 8s 21ms/step - loss: 0.4386 - accuracy: 0.8059 - val_loss: 0.5613 - val_accuracy: 0.7326
# Epoch 8/50
# 410/410 [==============================] - 9s 21ms/step - loss: 0.4464 - accuracy: 0.7974 - val_loss: 0.4834 - val_accuracy: 0.7759
# Epoch 9/50
# 410/410 [==============================] - 9s 21ms/step - loss: 0.4563 - accuracy: 0.7910 - val_loss: 0.4481 - val_accuracy: 0.7869
# Epoch 10/50
# 410/410 [==============================] - 8s 21ms/step - loss: 0.4520 - accuracy: 0.7952 - val_loss: 0.5255 - val_accuracy: 0.7350
# Epoch 11/50
# 410/410 [==============================] - 8s 21ms/step - loss: 0.4540 - accuracy: 0.7939 - val_loss: 0.5483 - val_accuracy: 0.7100
# Epoch 12/50
# 410/410 [==============================] - 9s 21ms/step - loss: 0.4560 - accuracy: 0.7948 - val_loss: 0.4916 - val_accuracy: 0.7686
# Epoch 13/50
50
# 410/410 [==============================] - 10s 24ms/step - loss: 0.6741 - accuracy: 0.6379 - val_loss: 0.6711 - val_accuracy: 0.6600

# %% [markdown]
# ## Evaluation of learning rates and momentum for Adam and SGD

# %%
Best_optimizer = optimizers.Adam(learning_rate=0.0001)

# %% [markdown]
# ## Regularization 1: Adjustments to the architecture
#
# - Add/remove layers
# - Adjust number of nodes

# %% [markdown]
# Deeper + narrower model

# %%
inputs = Input(shape=(96, 96, 3))
x = Conv2D(filters=16, kernel_size=3, activation="relu", padding='same')(inputs) # Filters 16 instead of 32
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=32, kernel_size=3, activation="relu", padding='same')(x)
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=64, kernel_size=3, activation="relu", padding='same')(x)     # Extra dense layer with 64 filters
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=64, kernel_size=3, activation="relu", padding='same')(x)
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=128, kernel_size=3, activation="relu", padding='same')(x)
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=256, kernel_size=3, activation="relu", padding='same')(x)
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=512, kernel_size=3, activation="relu", padding='same')(x)
x = Flatten()(x)

x = Dense(128, activation="relu")(x)											# Extra dense layer
x = Dense(128, activation="relu")(x)
outputs = Dense(2, activation="softmax")(x)
model = Model(inputs=inputs, outputs=outputs)
model.summary()

# ----- Model summary -----
model.summary()

# ----- Configure model -----
model.compile(optimizer=Best_optimizer,
			  loss='categorical_crossentropy',
			  metrics=['accuracy'])

# ----- Train model -----
history = model.fit(train,
					epochs = 50,
					validation_data= val)

# ----- Plot performance -----
plot_hist(history)
# Out:
# Model: "model_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_44 (InputLayer)       [(None, 96, 96, 3)]       0
#
#  conv2d_217 (Conv2D)         (None, 96, 96, 16)        448
#
#  max_pooling2d_174 (MaxPooli  (None, 48, 48, 16)       0
#  ng2D)
#
#  conv2d_218 (Conv2D)         (None, 48, 48, 32)        4640
#
#  max_pooling2d_175 (MaxPooli  (None, 24, 24, 32)       0
#  ng2D)
#
#  conv2d_219 (Conv2D)         (None, 24, 24, 64)        18496
#
#  max_pooling2d_176 (MaxPooli  (None, 12, 12, 64)       0
#  ng2D)
#
#  conv2d_220 (Conv2D)         (None, 12, 12, 64)        36928
#
#  max_pooling2d_177 (MaxPooli  (None, 6, 6, 64)         0
#  ng2D)
#
#  conv2d_221 (Conv2D)         (None, 6, 6, 128)         73856
#
#  max_pooling2d_178 (MaxPooli  (None, 3, 3, 128)        0
#  ng2D)
#
#  conv2d_222 (Conv2D)         (None, 3, 3, 256)         295168
#
#  max_pooling2d_179 (MaxPooli  (None, 1, 1, 256)        0
#  ng2D)
#
#  conv2d_223 (Conv2D)         (None, 1, 1, 512)         1180160
#
#  flatten_43 (Flatten)        (None, 512)               0
#
#  dense_45 (Dense)            (None, 128)               65664
#
#  dense_46 (Dense)            (None, 128)               16512
#
#  dense_47 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 1,692,130
# Trainable params: 1,692,130
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_44 (InputLayer)       [(None, 96, 96, 3)]       0
#
#  conv2d_217 (Conv2D)         (None, 96, 96, 16)        448
#
#  max_pooling2d_174 (MaxPooli  (None, 48, 48, 16)       0
#  ng2D)
#
#  conv2d_218 (Conv2D)         (None, 48, 48, 32)        4640
#
#  max_pooling2d_175 (MaxPooli  (None, 24, 24, 32)       0
#  ng2D)
#
#  conv2d_219 (Conv2D)         (None, 24, 24, 64)        18496
#
#  max_pooling2d_176 (MaxPooli  (None, 12, 12, 64)       0
#  ng2D)
#
#  conv2d_220 (Conv2D)         (None, 12, 12, 64)        36928
#
#  max_pooling2d_177 (MaxPooli  (None, 6, 6, 64)         0
#  ng2D)
#
#  conv2d_221 (Conv2D)         (None, 6, 6, 128)         73856
#
#  max_pooling2d_178 (MaxPooli  (None, 3, 3, 128)        0
#  ng2D)
#
#  conv2d_222 (Conv2D)         (None, 3, 3, 256)         295168
#
#  max_pooling2d_179 (MaxPooli  (None, 1, 1, 256)        0
#  ng2D)
#
#  conv2d_223 (Conv2D)         (None, 1, 1, 512)         1180160
#
#  flatten_43 (Flatten)        (None, 512)               0
#
#  dense_45 (Dense)            (None, 128)               65664
#
#  dense_46 (Dense)            (None, 128)               16512
#
#  dense_47 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 1,692,130
# Trainable params: 1,692,130
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 410/410 [==============================] - 10s 21ms/step - loss: 0.5389 - accuracy: 0.7228 - val_loss: 0.4809 - val_accuracy: 0.7558
# Epoch 2/50
# 410/410 [==============================] - 8s 18ms/step - loss: 0.4888 - accuracy: 0.7709 - val_loss: 0.4589 - val_accuracy: 0.7753
# Epoch 3/50
# 410/410 [==============================] - 7s 18ms/step - loss: 0.4729 - accuracy: 0.7816 - val_loss: 0.4530 - val_accuracy: 0.7759
# Epoch 4/50
# 410/410 [==============================] - 8s 18ms/step - loss: 0.4601 - accuracy: 0.7886 - val_loss: 0.4507 - val_accuracy: 0.7808
# Epoch 5/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.4472 - accuracy: 0.7964 - val_loss: 0.4449 - val_accuracy: 0.7808
# Epoch 6/50
# 410/410 [==============================] - 8s 18ms/step - loss: 0.4398 - accuracy: 0.7980 - val_loss: 0.4311 - val_accuracy: 0.7875
# Epoch 7/50
# 410/410 [==============================] - 7s 18ms/step - loss: 0.4274 - accuracy: 0.8054 - val_loss: 0.4313 - val_accuracy: 0.7863
# Epoch 8/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.4163 - accuracy: 0.8112 - val_loss: 0.4237 - val_accuracy: 0.7967
# Epoch 9/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.4028 - accuracy: 0.8193 - val_loss: 0.4162 - val_accuracy: 0.7985
# Epoch 10/50
# 410/410 [==============================] - 7s 18ms/step - loss: 0.3843 - accuracy: 0.8338 - val_loss: 0.4304 - val_accuracy: 0.7961
# Epoch 11/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.3691 - accuracy: 0.8408 - val_loss: 0.4438 - val_accuracy: 0.7882
# Epoch 12/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.3445 - accuracy: 0.8556 - val_loss: 0.5059 - val_accuracy: 0.7485
# Epoch 13/50
# Epoch 33/50
# 410/410 [==============================] - 8s 20ms/step - loss: 0.0444 - accuracy: 0.9848 - val_loss: 1.2129 - val_accuracy: 0.7698
# Epoch 34/50
# 410/410 [==============================] - 8s 20ms/step - loss: 0.0370 - accuracy: 0.9887 - val_loss: 1.2269 - val_accuracy: 0.7729
# Epoch 35/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0257 - accuracy: 0.9911 - val_loss: 1.2753 - val_accuracy: 0.7821
# Epoch 36/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0386 - accuracy: 0.9864 - val_loss: 1.5857 - val_accuracy: 0.7637
# Epoch 37/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0370 - accuracy: 0.9874 - val_loss: 1.4199 - val_accuracy: 0.7680
# Epoch 38/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0369 - accuracy: 0.9871 - val_loss: 1.3922 - val_accuracy: 0.7869
# Epoch 39/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0338 - accuracy: 0.9881 - val_loss: 1.3375 - val_accuracy: 0.7851
# Epoch 40/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0277 - accuracy: 0.9907 - val_loss: 1.2374 - val_accuracy: 0.7735
# Epoch 41/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0326 - accuracy: 0.9895 - val_loss: 1.2545 - val_accuracy: 0.7900
# Epoch 42/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0324 - accuracy: 0.9892 - val_loss: 1.1882 - val_accuracy: 0.7900
# Epoch 43/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0262 - accuracy: 0.9908 - val_loss: 1.3576 - val_accuracy: 0.7637
# Epoch 44/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0329 - accuracy: 0.9887 - val_loss: 1.3391 - val_accuracy: 0.7662
# Epoch 45/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0227 - accuracy: 0.9920 - val_loss: 1.4132 - val_accuracy: 0.7643
# Epoch 46/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0141 - accuracy: 0.9958 - val_loss: 1.4571 - val_accuracy: 0.7668
# Epoch 47/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0248 - accuracy: 0.9914 - val_loss: 1.3202 - val_accuracy: 0.7778
# Epoch 48/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0391 - accuracy: 0.9870 - val_loss: 1.1408 - val_accuracy: 0.7814
# Epoch 49/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0156 - accuracy: 0.9953 - val_loss: 1.4077 - val_accuracy: 0.7521
# Epoch 50/50
# 410/410 [==============================] - 8s 19ms/step - loss: 0.0193 - accuracy: 0.9923 - val_loss: 1.4200 - val_accuracy: 0.7723

# %% [markdown]
# Smaller model

# %%
inputs = Input(shape=(96, 96, 3))
x = Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=128, kernel_size=3, activation="relu")(x) 
x = Conv2D(filters=128, kernel_size=3, activation="relu")(x) #Pooling layer removed and amount of filters set to 128
x = MaxPooling2D(pool_size=2)(x)
x = Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = Flatten()(x)
outputs = Dense(2, activation="softmax")(x)
model = Model(inputs=inputs, outputs=outputs)


# ----- Model summary -----
model.summary()

# ----- Configure model -----
model.compile(optimizer=Best_optimizer,
			  loss='categorical_crossentropy',
			  metrics=['accuracy'])

# ----- Train model -----
history = model.fit(train,
					epochs = 50,
					validation_data= val)

# ----- Plot performance -----
plot_hist(history)
# Out:
# Model: "model_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_46 (InputLayer)       [(None, 96, 96, 3)]       0
#
#  conv2d_229 (Conv2D)         (None, 94, 94, 32)        896
#
#  max_pooling2d_183 (MaxPooli  (None, 47, 47, 32)       0
#  ng2D)
#
#  conv2d_230 (Conv2D)         (None, 45, 45, 64)        18496
#
#  max_pooling2d_184 (MaxPooli  (None, 22, 22, 64)       0
#  ng2D)
#
#  conv2d_231 (Conv2D)         (None, 20, 20, 128)       73856
#
#  conv2d_232 (Conv2D)         (None, 18, 18, 128)       147584
#
#  max_pooling2d_185 (MaxPooli  (None, 9, 9, 128)        0
#  ng2D)
#
#  conv2d_233 (Conv2D)         (None, 7, 7, 256)         295168
#
#  flatten_45 (Flatten)        (None, 12544)             0
#
#  dense_49 (Dense)            (None, 2)                 25090
#
# =================================================================
# Total params: 561,090
# Trainable params: 561,090
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 410/410 [==============================] - 11s 25ms/step - loss: 0.5167 - accuracy: 0.7502 - val_loss: 0.4380 - val_accuracy: 0.7918
# Epoch 2/50
# 410/410 [==============================] - 10s 24ms/step - loss: 0.4800 - accuracy: 0.7743 - val_loss: 0.4464 - val_accuracy: 0.7869
# Epoch 3/50
# 410/410 [==============================] - 10s 24ms/step - loss: 0.4699 - accuracy: 0.7795 - val_loss: 0.4497 - val_accuracy: 0.7882
# Epoch 4/50
# 410/410 [==============================] - 10s 24ms/step - loss: 0.4580 - accuracy: 0.7879 - val_loss: 0.4516 - val_accuracy: 0.7985
# Epoch 5/50
# 410/410 [==============================] - 10s 25ms/step - loss: 0.4476 - accuracy: 0.7913 - val_loss: 0.4458 - val_accuracy: 0.7991
# Epoch 6/50
# 410/410 [==============================] - 10s 25ms/step - loss: 0.4296 - accuracy: 0.8036 - val_loss: 0.4601 - val_accuracy: 0.7753
# Epoch 7/50
# 410/410 [==============================] - 10s 25ms/step - loss: 0.4161 - accuracy: 0.8103 - val_loss: 0.4418 - val_accuracy: 0.7912
# Epoch 8/50
# 410/410 [==============================] - 10s 25ms/step - loss: 0.4038 - accuracy: 0.8151 - val_loss: 0.4474 - val_accuracy: 0.7827
# Epoch 9/50
# 410/410 [==============================] - 10s 25ms/step - loss: 0.3868 - accuracy: 0.8270 - val_loss: 0.4518 - val_accuracy: 0.7753
# Epoch 10/50
# 410/410 [==============================] - 10s 25ms/step - loss: 0.3676 - accuracy: 0.8385 - val_loss: 0.4265 - val_accuracy: 0.7998
# Epoch 11/50
# 410/410 [==============================] - 10s 25ms/step - loss: 0.3536 - accuracy: 0.8474 - val_loss: 0.4489 - val_accuracy: 0.7827
# ## Evaluation of architectures

# %% [markdown]
# ## Increase amount of data
#
# 5/10%

# %%
data_dir = 'C:/Users/chrse/Desktop/project_aml'
BATCH_SIZE = 32
train, test, val = load_data(data_dir, perc=5, batch_size=BATCH_SIZE)

# %%
# Best model

# %%
data_dir = 'C:/Users/chrse/Desktop/project_aml'
BATCH_SIZE = 32
train, test, val = load_data(data_dir, perc=10, batch_size=BATCH_SIZE)

# %%
# Best model

# %% [markdown]
# ## Regularization
#
# Regarding early stopping, we prefer to save the best model instead and let the model train for the chosen epochs.
#
# - Augmentation
# - L1/L2
# - Batch normalization
# - Dropout

# %% [markdown]
# def augment_layer(size: Optional[int] = None,
#                  flip: Optional[Literal["horizontal_and_vertical", "horizontal", "vertical"]] = None,
#                  rotation: Optional[float] = None,
#                  zoom: Optional[tuple[float, float]] =,
#                  contrast: Optional[float] = None,
#                  brightness: Optional[float] = None) -> layers:

# %%
# Augmentation
x = augment_layer(flip="horizontal_and_vertical", rotation=180, zoom=0.15, contrast=0.5)(inputs)

# ----- Model summary -----
model.summary()

# ----- Configure model -----
model.compile(optimizer=Best_optimizer,
			  loss='categorical_crossentropy',
			  metrics=['accuracy'])

# ----- Train model -----
history = model.fit(train,
					epochs = 30,
					validation_data= val)

# ----- Plot performance -----
plot_hist(history)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# Model: "model_65"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_66 (InputLayer)       [(None, 96, 96, 3)]       0
#
#  conv2d_327 (Conv2D)         (None, 96, 96, 16)        448
#
#  max_pooling2d_262 (MaxPooli  (None, 48, 48, 16)       0
#  ng2D)
#
#  conv2d_328 (Conv2D)         (None, 48, 48, 32)        4640
#
#  max_pooling2d_263 (MaxPooli  (None, 24, 24, 32)       0
#  ng2D)
#
#  conv2d_329 (Conv2D)         (None, 24, 24, 64)        18496
#
#  max_pooling2d_264 (MaxPooli  (None, 12, 12, 64)       0
#  ng2D)
#
#  conv2d_330 (Conv2D)         (None, 12, 12, 64)        36928
#
#  max_pooling2d_265 (MaxPooli  (None, 6, 6, 64)         0
#  ng2D)
#
#  conv2d_331 (Conv2D)         (None, 6, 6, 128)         73856
#
#  max_pooling2d_266 (MaxPooli  (None, 3, 3, 128)        0
#  ng2D)
#
#  conv2d_332 (Conv2D)         (None, 3, 3, 256)         295168
#
#  max_pooling2d_267 (MaxPooli  (None, 1, 1, 256)        0
#  ng2D)
#
#  conv2d_333 (Conv2D)         (None, 1, 1, 512)         1180160
#
#  flatten_65 (Flatten)        (None, 512)               0
#
#  dense_67 (Dense)            (None, 128)               65664
#
#  dense_68 (Dense)            (None, 128)               16512
#
#  dense_69 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 1,692,130
# Trainable params: 1,692,130
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 82/82 [==============================] - 25s 287ms/step - loss: 0.0620 - accuracy: 0.9821 - val_loss: 0.9050 - val_accuracy: 0.7622
# Epoch 2/30
# 31/82 [==========>...................] - ETA: 14s - loss: 0.0850 - accuracy: 0.9698
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\chrse\Desktop\applied_ML_faelles\exam\question_2\faelles.ipynb Cell 28 in <cell line: 13>()
#       <a href='vscode-notebook-cell:/c%3A/Users/chrse/Desktop/applied_ML_faelles/exam/question_2/faelles.ipynb#X45sZmlsZQ%3D%3D?line=7'>8</a> model.compile(optimizer=Best_optimizer,
#       <a href='vscode-notebook-cell:/c%3A/Users/chrse/Desktop/applied_ML_faelles/exam/question_2/faelles.ipynb#X45sZmlsZQ%3D%3D?line=8'>9</a> 			  loss='categorical_crossentropy',
#      <a href='vscode-notebook-cell:/c%3A/Users/chrse/Desktop/applied_ML_faelles/exam/question_2/faelles.ipynb#X45sZmlsZQ%3D%3D?line=9'>10</a> 			  metrics=['accuracy'])
#      <a href='vscode-notebook-cell:/c%3A/Users/chrse/Desktop/applied_ML_faelles/exam/question_2/faelles.ipynb#X45sZmlsZQ%3D%3D?line=11'>12</a> # ----- Train model -----
# ---> <a href='vscode-notebook-cell:/c%3A/Users/chrse/Desktop/applied_ML_faelles/exam/question_2/faelles.ipynb#X45sZmlsZQ%3D%3D?line=12'>13</a> history = model.fit(train,
#      <a href='vscode-notebook-cell:/c%3A/Users/chrse/Desktop/applied_ML_faelles/exam/question_2/faelles.ipynb#X45sZmlsZQ%3D%3D?line=13'>14</a> 					epochs = 30,
#      <a href='vscode-notebook-cell:/c%3A/Users/chrse/Desktop/applied_ML_faelles/exam/question_2/faelles.ipynb#X45sZmlsZQ%3D%3D?line=14'>15</a> 					validation_data= val)
#      <a href='vscode-notebook-cell:/c%3A/Users/chrse/Desktop/applied_ML_faelles/exam/question_2/faelles.ipynb#X45sZmlsZQ%3D%3D?line=16'>17</a> # ----- Plot performance -----
#      <a href='vscode-notebook-cell:/c%3A/Users/chrse/Desktop/applied_ML_faelles/exam/question_2/faelles.ipynb#X45sZmlsZQ%3D%3D?line=17'>18</a> plot_hist(history)
#
# File c:\Users\chrse\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chrse\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File c:\Users\chrse\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chrse\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chrse\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\chrse\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\chrse\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chrse\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File c:\Users\chrse\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
def do_nothing(x):
    return x

images, labels = preprocess_data(train, do_nothing)

img = images[5]
plt.imshow(img)

# %%
aug_img = augment_layer(flip="horizontal_and_vertical", rotation=180, contrast=0.5)(img)
plt.imshow(aug_img)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# L1

# Best model

# ----- Model summary -----
model.summary()

# ----- Configure model -----
model.compile(optimizer=Best_optimizer,
			  loss='categorical_crossentropy',
			  metrics=['accuracy'])

# ----- Train model -----
history = model.fit(train,
					epochs = 30,
					validation_data= val)

# ----- Plot performance -----
plot_hist(history)

# %%
# L2

# Best model

# ----- Model summary -----
model.summary()

# ----- Configure model -----
model.compile(optimizer=Best_optimizer,
			  loss='categorical_crossentropy',
			  metrics=['accuracy'])

# ----- Train model -----
history = model.fit(train,
					epochs = 30,
					validation_data= val)

# ----- Plot performance -----
plot_hist(history)

# %% [markdown]
# # ----- Relatively Simple Convnet from DLPR -----
# inputs = Input(shape=(96, 96, 3))
# x = Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
# x = MaxPooling2D(pool_size=2)(x)
# x = Conv2D(filters=64, kernel_size=3, activation="relu")(x)
# x = MaxPooling2D(pool_size=2)(x)
# x = Conv2D(filters=128, kernel_size=3, activation="relu")(x)
# x = MaxPooling2D(pool_size=2)(x)
# x = Conv2D(filters=256, kernel_size=3, activation="relu")(x)
# x = MaxPooling2D(pool_size=2)(x)
# x = Conv2D(filters=256, kernel_size=3, activation="relu")(x)
# x = Flatten()(x)
# outputs = Dense(2, activation="softmax")(x)
# model = Model(inputs=inputs, outputs=outputs)
#
# # ----- Model summary -----
# model.summary()
#
# # ----- Configure model -----
# model.compile(optimizer='adam',
# 			  loss='categorical_crossentropy',
# 			  metrics=['accuracy'])
#
# # ----- Train model -----
# history = model.fit(train,
# 					epochs = 2,
# 					validation_data= val)
#
# # ----- Plot performance -----
# plot_hist(history)

# %% [markdown]
# First model = Simple CNN from DLWP -->
